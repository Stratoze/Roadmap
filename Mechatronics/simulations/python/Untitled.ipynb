# %%
name = "Kohaku"
print(f"hello {name}")

a = 3
b = 4
print(a + b)
print(a / b)
print(a // b)

angles = [0, 30, 60]
print(angles)
print(angles * 2)
# Out:
# hello Kohaku
# 7
# 0.75
# 0
# [0, 30, 60]
# [0, 30, 60, 0, 30, 60]
